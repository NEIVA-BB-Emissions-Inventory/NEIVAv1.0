# %% [markdown]
# # **Add a new EF table and update the Recommended EF table**

# %% [markdown]
# ## **1. Setting up the NEIVA database in the colab environment.**

# %%
# !pip install mysql-connector-python # Install the necessary package to connect Python with MySQL databases.
# !pip install pubchempy
# !apt-get update
# !pip install pymysql
# !apt-get -y install mysql-server    # Install the MySQL server on the Colab environment.
# !service mysql start                # With MySQL install, this starts the server.

# Setting the password. Here 'root' is used as password.

# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH 'mysql_native_password' BY 'root';FLUSH PRIVILEGES;"

# %%
# Remove the existing NEIVA repository if it exists.
# !rm -rf NEIVA
# Download the NEIVA repository from GitHub
# !git clone https://github.com/NEIVA-BB-emissions-Inventory/NEIVA.git
# Out:
# Cloning into 'NEIVA'...
# remote: Enumerating objects: 1187, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 1187 (delta 150), reused 131 (delta 71), pack-reused 969
# Receiving objects: 100% (1187/1187), 4.27 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (880/880), done.

# %%
# Check if the repository is downloaded by listing its contents.
# !ls NEIVA
# Out:
#  data	      'Jupyter notebooks'   NEIVA_logo.png   python_scripts
#  __init__.py   LICENSE		    neivapy.py	     README.md

# %%
# Drop MySQL databases to clean up resources
# !mysql -u root -proot -e "drop database backend_db"
# !mysql -u root -proot -e "drop database primary_db"
# !mysql -u root -proot -e "drop database raw_db"
# !mysql -u root -proot -e "drop database legacy_db"
# !mysql -u root -proot -e "drop database neiva_output_db"

# %%
# Initialize MySQL databases and import data from NEIVA SQL files
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS backend_db"
# !mysql -u root -proot backend_db < NEIVA/data/backend_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS legacy_db"
# !mysql -u root -proot legacy_db < NEIVA/data/legacy_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS neiva_output_db"
# !mysql -u root -proot neiva_output_db < NEIVA/data/neiva_output_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS primary_db"
# !mysql -u root -proot primary_db < NEIVA/data/primary_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS raw_db"
# !mysql -u root -proot raw_db < NEIVA/data/raw_db.sql
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.
# mysql: [Warning] Using a password on the command line interface can be insecure.

# %% [markdown]
# ## **2. Import the 'neivapy' package and other essential python libraries**

# %%
import NEIVA.neivapy as nv

# %%
from sqlalchemy import text
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# ## **3. Establish connection with the databases.**

# %%
bk_db=nv.connect_db('backend_db')
primary_db=nv.connect_db('primary_db')
raw_db=nv.connect_db('raw_db')
legacy_db=nv.connect_db('legacy_db')
neiva_output_db=nv.connect_db('neiva_output_db')

# %% [markdown]
# ## **4. Prepare a new table and insert in the primary_db (pdb).**

# %%
new_df=pd.DataFrame()
data = {
    'mm': [44,28,94, 136, 136],
    'formula': ['CO2','CO','C6H6O', 'C7H8', 'C10H16'],
    'compound': ['Carbon dioxide','Carbon monoxide','Phenol','Toluene','New_compound'],
    'pollutant_category':['inorganic gas','inorganic gas','NMOC_g','NMOC_g','NMOC_g'],
    'EF_new_data_temperate_forest':[1699.05,78.52,100,200,300],
    'id':[np.nan, np.nan, np.nan, np.nan, np.nan]
}
new_df = pd.DataFrame(data)

# %%
# Assign id.
new_df = nv.assign_id (new_df)
# Set an id for the unknown compound.
new_df.loc[4,'id']='InChI=new_id'
new_df
# Out:
#     mm formula         compound pollutant_category  \
# 0   44     CO2   Carbon dioxide      inorganic gas
# 1   28      CO  Carbon monoxide      inorganic gas
# 2   94   C6H6O           Phenol             NMOC_g
# 3  136    C7H8          Toluene             NMOC_g
# 4  136  C10H16     New_compound             NMOC_g
#
#    EF_new_data_temperate_forest                                        id
# 0                       1699.05                       InChI=1S/CO2/c2-1-3
# 1                         78.52                          InChI=1S/CO/c1-2
# 2                        100.00   InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H
# 3                        200.00  InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h2-6H,1H3
# 4                        300.00                              InChI=new_id

# %%
# Inserting the table in primary db.
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:root@localhost/"+'primary_db')
new_df.to_sql(name='pdb_tmf_new_table',con=engine, if_exists='replace', index=False)
# Out:
# 5

# %%
# Check the new table.
# !mysql -u root -proot -e "use primary_db; select * from pdb_tmf_new_table;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +------+---------+-----------------+--------------------+------------------------------+------------------------------------------+
# | mm   | formula | compound        | pollutant_category | EF_new_data_temperate_forest | id                                       |
# +------+---------+-----------------+--------------------+------------------------------+------------------------------------------+
# |   44 | CO2     | Carbon dioxide  | inorganic gas      |                      1699.05 | InChI=1S/CO2/c2-1-3                      |
# |   28 | CO      | Carbon monoxide | inorganic gas      |                        78.52 | InChI=1S/CO/c1-2                         |
# |   94 | C6H6O   | Phenol          | NMOC_g             |                          100 | InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H  |
# |  136 | C7H8    | Toluene         | NMOC_g             |                          200 | InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h2-6H,1H3 |
# |  136 | C10H16  | New_compound    | NMOC_g             |                          300 | InChI=new_id                             |
# +------+---------+-----------------+--------------------+------------------------------+------------------------------------------+

# %% [markdown]
# ## **5. Update the information table**

# %%
# !mysql -u root -proot -e "use backend_db;INSERT INTO bkdb_info_efcol (efcol, fire_type, measurement_type, study, fuel_type, year, legend, MCE) VALUES ('EF_new_data_temperate_forest', 'temperate forest', 'lab', 'new_data', 'ponderosa pine', 2018, 'new data', 0.932)"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.

# %%
bk_db=nv.connect_db('backend_db')
efcoldf=pd.read_sql(text('select * from bkdb_info_efcol'), con=bk_db)
efcoldf[efcoldf['fire_type']=='temperate forest'][efcoldf['study']=='new_data']
# Out:
#                             efcol         fire_type measurement_type  \
# 250  EF_new_data_temperate_forest  temperate forest              lab
#
#         study       fuel_type cookstove_type cookstove_name    year  \
# 250  new_data  ponderosa pine           None           None  2018.0
#
#      year_akagi_data    legend    MCE
# 250              NaN  new data  0.932

# %% [markdown]
# ## **6. Executing the data integration and data processig steps**

# %%
# The pdb database tabled are integrated into a single table.
int_df=nv.integrate_tables()
# Out:
# 0           pdb_akagi11_boreal_forest
# 1               pdb_akagi11_chaparral
# 2        pdb_akagi11_charcoal_burning
# 3         pdb_akagi11_charcoal_making
# 4               pdb_akagi11_cookstove
# 5            pdb_akagi11_crop_residue
# 6            pdb_akagi11_dung_burning
# 7         pdb_akagi11_garbage_burning
# 8            pdb_akagi11_open_cooking
# 9     pdb_akagi11_pasture_maintenance
# 10                   pdb_akagi11_peat
# 11                pdb_akagi11_savanna
# 12       pdb_akagi11_temperate_forest
# 13        pdb_akagi11_tropical_forest
# 14                    pdb_bf_hayden22
# 15                       pdb_coffey17
# 16                    pdb_cr_holder17
# 17                     pdb_cr_lasko18
# 18                       pdb_cr_liu16
# 19                      pdb_fleming18
# 20                  pdb_gb_yokelson13
# 21                        pdb_goetz18
# 22                        pdb_hatch15
# 23                        pdb_hatch17
# 24                   pdb_jayarathne14
# 25                   pdb_jayarathne18
# 26                          pdb_may14
# 27                 pdb_p_jayarathne18
# 28                   pdb_p_roulston18
# 29                      pdb_p_smith17
# 30                  pdb_p_stockwell16
# 31                     pdb_p_watson19
# 32                      pdb_pokhrel16
# 33                    pdb_selimovic18
# 34                    pdb_stockwell15
# 35                    pdb_stockwell16
# 36              pdb_sv_desservettaz20
# 37                pdb_tmf_gkatzelis23
# 38                      pdb_tmf_liu17
# 39                   pdb_tmf_muller16
# 40                  pdb_tmf_new_table
# 41                   pdb_tmf_permar21
# 42                       pdb_travis23
# 43                  pdb_trf_hodgson18
# Name: tbl_names, dtype: object
# Formula column ordered-
# +----------+------------------+
# | Formula  | Formula(ordered) |
# +----------+------------------+
# |   HNCO   |       CHNO       |
# |  C4HON   |      C4HNO       |
# | C6H3O2N  |     C6H3NO2      |
# |  C3HO5N  |      C3HNO5      |
# |  C8H5ON  |      C8H5NO      |
# | C7H5O2N  |     C7H5NO2      |
# | C6H3O3N  |     C6H3NO3      |
# |  C9H5ON  |      C9H5NO      |
# | C10H9ON  |     C10H9NO      |
# | C9H9O2N  |     C9H9NO2      |
# | C10H9O2N |     C10H9NO2     |
# | CH3COOH  |      C2H4O2      |
# |   OCS    |       COS        |
# | CH3ONO2  |      CH3NO3      |
# |  CCl2F2  |      CF2Cl2      |
# | C2Cl3F3  |     C2F3Cl3      |
# |  CCl3F   |      CFCl3       |
# | C2O4H3N  |     C2H3NO4      |
# | C2O4H5N  |     C2H5NO4      |
# | C3O3H5N  |     C3H5NO3      |
# | C3O4H7N  |     C3H7NO4      |
# | C4O4H7N  |     C4H7NO4      |
# | C4O4H9N  |     C4H9NO4      |
# | C4O5H7N  |     C4H7NO5      |
# | C5O4H9N  |     C5H9NO4      |
# | C5O5H9N  |     C5H9NO5      |
# |  CO3H4   |      CH4O3       |
# |  C2O3H4  |      C2H4O3      |
# |  C3O3H6  |      C3H6O3      |
# |  C4O3H8  |      C4H8O3      |
# | C5O3H10  |     C5H10O3      |
# |  C3O3H8  |      C3H8O3      |
# | C2O4H5N  |     C2H5NO4      |
# | C3O4H7N  |     C3H7NO4      |
# |  ClNO2   |      NO2Cl       |
# +----------+------------------+
#
# Data Integration process COMPLETE!
# +-------------------+---------+
# |       Check       |  Output |
# +-------------------+---------+
# |   Duplicate IDs   |  Clear  |
# | Row with all NaNs |  Clear  |
# |   formula column  | Cleaned |
# +-------------------+---------+
# Length of Integrated dataset :1378

# %%
# The integrated EF dataset is produced.
int_df[['mm','formula','compound','EF_new_data_temperate_forest']][int_df['EF_new_data_temperate_forest'].notna()]
# Out:
#          mm formula         compound  EF_new_data_temperate_forest
# 0      44.0     CO2   carbon dioxide                       1699.05
# 1      28.0      CO  carbon monoxide                         78.52
# 71     92.0    C7H8          Toluene                        200.00
# 75     94.0   C6H6O           Phenol                        100.00
# 1355  136.0  C10H16     New_compound                        300.00

# %%
nmogdf=nv.select_nmog(int_df)
nmogdf=nv.assign_study_column(nmogdf)
# Out:
# Non-Methane Organic Compounds Gas-Phase (NMOC_g) Data Frame: [ROW, COLUMN] =[1190 256]

# %%
# The similar lumped compounds are merged.
r_iddf, iddf =nv.merge_lumped_compound_same_formula(nmogdf)
# Out:
# ______________________________________________________________________________________________________________
# Formula-C4H8 Merged compounds-
#                       compound     study
# 0  Butenes + other hydrocarbon    koss18
# 1         Isobutene + 1-Butene  permar21
# 2                      Butenes  permar21
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H7N Merged compounds-
#                           compound            study
# 0  Dihydropyrrole + butane nitrile  permar21,koss18
# 1                          unknown         hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H10 Merged compounds-
#                   compound            study
# 0  Pentene + methyl butene  permar21,koss18
# 1             assorted hcs      stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C2H5NO2 Merged compounds-
#                         compound     study
# 0  Nitroethane or ethane nitrite    koss18
# 1    Nitroethane + Ethyl nitrite  permar21
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C2H4O3 Merged compounds-
#                                        compound   study
# 0                                       unknown  koss18
# 1  Peroxyacetic acid/hydroperoxy glycolaldehyde   liu17
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H8 Merged compounds-
#                                    compound                 study
# 0                                   unknown                koss18
# 1  Methyl Cyclopentadiene ( isomer 1, C6H8)  Akagi_11(yokelson13)
# 2                                  hexenyne  Akagi_11(yokelson13)
# 3                              Monoterpenes                 liu16
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H10 Merged compounds-
#                  compound                 study
# 0                 unknown                koss18
# 1            assorted hcs           stockwell15
# 2  Other C6H10 (isomer_1)  Akagi_11(yokelson13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H12 Merged compounds-
#                      compound                                   study
# 0                     unknown                                  koss18
# 1                assorted hcs                             stockwell15
# 2  Hexenes (sum of 3 isomers)  Akagi_11(yokelson13),Akagi_11(akagi13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H14 Merged compounds-
#             compound                               study
# 0            unknown                              koss18
# 1  2+3-methylpentane  hayden22,liu17,Akagi_11(simpson11)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H9NO Merged compounds-
#           compound        study
# 0          unknown       koss18
# 1  assorted amides  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H11NO Merged compounds-
#           compound        study
# 0          unknown       koss18
# 1  assorted amines  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H6 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# 2  unknown     hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H4O Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C2H7NO3 Merged compounds-
#   compound     study
# 0  unknown    koss18
# 1  unknown  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H10 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H3O2 Merged compounds-
#   compound     study
# 0  unknown    koss18
# 1  unknown  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H8O Merged compounds-
#                                             compound  \
# 0  2,5-dimethyl furan + 2-ethylfuran + other C2 s...
# 1                                       C6 Carbonyls
#
#                                        study
# 0       gkatzelis23,travis23,permar21,koss18
# 1  Akagi_11(yokelson11),Akagi_11(yokelson08)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H12 Merged compounds-
#        compound        study
# 0       unknown       koss18
# 1  assorted hcs  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H3NO2 Merged compounds-
#   compound     study
# 0  unknown    koss18
# 1  unknown  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H10O Merged compounds-
#                                             compound                     study
# 0  Methyl cyclopentanone + cyclohexanone + other ...  hayden22,permar21,koss18
# 1                                            Unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H8O2 Merged compounds-
#                            compound            study
# 0                           unknown      stockwell15
# 1  Methyl methacrylate + other HCO2  hayden22,koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H12O Merged compounds-
#                    compound                          study
# 0       hexanal + hexanones                permar21,koss18
# 1  other substituted furans  hayden22,Akagi_11(yokelson08)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H10O2 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H10 Merged compounds-
#                                          compound  \
# 0                                    C8 Aromatics
# 1  Ethyl benzene + m-xylene + p-xylene + o-xylene
# 2                                      m+p-xylene
# 3                                    C8 Aromatics
#
#                                                study
# 0                      hayden22,Akagi_11(yokelson13)
# 1  gkatzelis23,koss18,stockwell15,Akagi_11(yokels...
# 2  travis23,permar21,fleming18,holder17,hatch17,l...
# 3                                           permar21
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H8O Merged compounds-
#                               compound  \
# 0              Cresols(Methoxyphenols)
# 1  2-Methylphenol (=o-cresol) + anisol
#
#                                            study
# 0                                    stockwell15
# 1  gkatzelis23,travis23,hayden22,permar21,koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H12 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  Unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H5O2 Merged compounds-
#   compound     study
# 0  unknown    koss18
# 1  unknown  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H6O2 Merged compounds-
#                                             compound  \
# 0  5-Methyl furfural +Benzene diols (=catechol, r...
# 1                             Catechol(Benzenediols)
#
#                                            study
# 0  gkatzelis23,travis23,hayden22,permar21,koss18
# 1                                    stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H10O Merged compounds-
#                  compound                     study
# 0  C3 furan + various HCO  hayden22,permar21,koss18
# 1                 unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H14 Merged compounds-
#   compound        study
# 0  unknown  stockwell15
# 1  unknown       koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H4O3 Merged compounds-
#                              compound                     study
# 0  5-Hydroxy 2-furfural/2-furoic acid  hayden22,permar21,koss18
# 1                             unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H10O2 Merged compounds-
#                       compound                     study
# 0  C6 Diones + C6 1-DBE esters  hayden22,permar21,koss18
# 1                      Unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H8O3 Merged compounds-
#                                             compound                     study
# 0                      Isoprene hydroperoxyaldehydes               liu17,liu16
# 1                                            unknown               stockwell15
# 2  5-hydroxymethyl tetrahydro 2-furanone + 5-hydr...  hayden22,permar21,koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C6H12O2 Merged compounds-
#     compound                     study
# 0  C6 esters  hayden22,permar21,koss18
# 1    Unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H8 Merged compounds-
#                            compound        study
# 0                           unknown  stockwell15
# 1  Indene + propynyl benzene isomer       koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C5H10O3 Merged compounds-
#                                             compound   study
# 0                                            unknown  koss18
# 1  Isoprene hydroxy hydroperoxides/isoprene epoxy...   liu17
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H10 Merged compounds-
#                                        compound                     study
# 0                                  assorted hcs               stockwell15
# 1  Indane + methyl styrenes + propenyl benzenes  hayden22,permar21,koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H9NO3 Merged compounds-
#                              compound     study
# 0                             unknown    koss18
# 1  Isobutyl nitrate + 2-Butyl nitrate  permar21
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H9N Merged compounds-
#            compound     study
# 0  Dihydro pyridine    koss18
# 1           unknown  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H12 Merged compounds-
#                         compound  \
# 0                   C9 Aromatics
# 1  trimethylbenzene;assorted hcs
# 2     1-ethyl-3-,4-methylbenzene
#
#                                              study
# 0  permar21,koss18,yokelson13,Akagi_11(yokelson13)
# 1        gkatzelis23,travis23,hayden22,stockwell15
# 2          hatch15,yokelson13,Akagi_11(yokelson13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C3H7NO4 Merged compounds-
#                   compound   study
# 0                  unknown  koss18
# 1  Propene hydroxynitrates   liu17
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H14 Merged compounds-
#   compound        study
# 0  unknown  stockwell15
# 1  unknown       koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H10O2 Merged compounds-
#                                 compound        study
# 0            cyclohexene carboxylic acid     hayden22
# 1                                unknown       koss18
# 2                                unknown  stockwell15
# 3  undaturated C6 cyclic carboxylic acid     hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H10 Merged compounds-
#              compound                                    study
# 0  Dihydronaphthalene  koss18,stockwell15,Akagi_11(yokelson13)
# 1  1-,3-methyl indene                     Akagi_11(yokelson13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H12 Merged compounds-
#                                   compound  \
# 0  Methyl propenyl benzene + ethyl styrene
# 1                             ethylstyrene
#
#                                     study
# 0                                  koss18
# 1  hayden22,permar21,Akagi_11(yokelson13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H14 Merged compounds-
#                          compound  \
# 0                   C10 Aromatics
# 1  Methyl-n-Propylbenzene isomers
# 2            Ethyl Xylene isomers
#
#                                              study
# 0  permar21,koss18,yokelson13,Akagi_11(yokelson13)
# 1                    hayden22,Akagi_11(yokelson13)
# 2                             Akagi_11(yokelson13)
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H6O2 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C4H9NO4 Merged compounds-
#                  compound           study
# 0                 unknown          koss18
# 1  Butene hydroxynitrates  travis23,liu17
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H16 Merged compounds-
#             compound                                              study
# 0       Monoterpenes  permar21,koss18,liu17,yokelson13,Akagi_11(yoke...
# 1  terpenes(-pinene)          gkatzelis23,travis23,hayden22,stockwell15
# 2  -Pinene + Myrcene                                  travis23,permar21
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H12O Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C7H6O3 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C8H12O2 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  Unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H10O Merged compounds-
#               compound                     study
# 0  dimethylbenzofurans  hayden22,permar21,koss18
# 1              unknown               stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C11H14 Merged compounds-
#   compound        study
# 0  Unknown  stockwell15
# 1  unknown       koss18
# 2  unknown     hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C11H16 Merged compounds-
#         compound                                            study
# 0  C11 aromatics  permar21,koss18,yokelson13,Akagi_11(yokelson13)
# 1        Unknown                                      stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C9H8O2 Merged compounds-
#   compound        study
# 0  unknown  stockwell15
# 1  unknown       koss18
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C10H14O Merged compounds-
#           compound     study
# 0          unknown    koss18
# 1  camphor/isomers  hayden22
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C11H18 Merged compounds-
#   compound        study
# 0  unknown       koss18
# 1  Unknown  stockwell15
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
# Formula-C11H12O Merged compounds-
#                            compound     study
# 0  C11 aromatics/pentamethylbenzene  hayden22
# 1                           unknown    koss18
# ______________________________________________________________________________________________________________
# Rows merging process is verified.
# +--------------------------------------------------------------------------------------------+
# Length of merged dataframe : 59
# Length of dataframe containing lumped compound(>1) of a unique formula : 133
# +--------------------------------------------------------------------------------------------+

# %%
nmogdf=nv.insert_rdf_nmogdf(nmogdf,r_iddf,iddf)
# Out:
# Length of NMOC_g dataset: 1116

# %%
lc_spec_df=nv.sync_lumped_compound_and_speciation(nmogdf)
# Out:
# ***************************************************************************************
# This is a data sorting step. The following steps are executed:
# 1. Split a lumped compound into individual components, assign id to the componenets
# 2. Search the ids within the integrated dataset
# 3. Align the lumped compound and individual compounds if found.
# ***************************************************************************************
# Lumped compound- Ethylamine + dimethylamine
# Assigned id to individual compound:  Ethylamine
# Assigned id to individual compound:  dimethylamine
# __________________________________________________________________
# Lumped compound- 1,3-Butadiene + 1,2-Butadiene
# Assigned id to individual compound:  1,3-Butadiene
# Assigned id to individual compound:  1,2-Butadiene
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- 1-butyne + 2-butyne
# Assigned id to individual compound:  1-butyne
# Assigned id to individual compound:  2-butyne
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- methyl isocyanate + hydroxyacetonitrile
# Unable to assign id to inidividual compound:  methyl isocyanate
# Unable to assign id to inidividual compound:  hydroxyacetonitrile
# __________________________________________________________________
# Lumped compound- Acetone + Propanal
# Unable to assign id to inidividual compound:  Acetone
# Assigned id to individual compound:  Propanal
# __________________________________________________________________
# Lumped compound- Acetic acid + glycolaldehyde
# Assigned id to individual compound:  Acetic acid
# Assigned id to individual compound:  glycolaldehyde
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- Methyl vinyl ketone+methacrolein+crotonaldehyde
# Assigned id to individual compound:  Methyl vinyl ketone
# Assigned id to individual compound:  methacrolein
# Assigned id to individual compound:  crotonaldehyde
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- Buteneamines + Tetrahydropyrrole
# Unable to assign id to inidividual compound:  Buteneamines
# Assigned id to individual compound:  Tetrahydropyrrole
# __________________________________________________________________
# Lumped compound- Methyl glyoxal+acrylic acid
# Assigned id to individual compound:  Methyl glyoxal
# Assigned id to individual compound:  acrylic acid
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- Methyl ethyl ketone+butanal+2-methylpopanal
# Assigned id to individual compound:  Methyl ethyl ketone
# Assigned id to individual compound:  butanal
# Unable to assign id to inidividual compound:  2-methylpopanal
# __________________________________________________________________
# Lumped compound- methyl acetate + ethyl formate + hydroxyacetone
# Assigned id to individual compound:  methyl acetate
# Assigned id to individual compound:  ethyl formate
# Assigned id to individual compound:  hydroxyacetone
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- Pyridine + pentadienenitriles
# Assigned id to individual compound:  Pyridine
# Unable to assign id to inidividual compound:  pentadienenitriles
# __________________________________________________________________
# Lumped compound- 3-methyl-2-butanone + 2-methylbutanal+3-methylbutanal+2-pentanone +3-pentanone
# Assigned id to individual compound:  3-methyl-2-butanone
# Assigned id to individual compound:  2-methylbutanal
# Assigned id to individual compound:  3-methylbutanal
# Assigned id to individual compound:  2-pentanone
# Assigned id to individual compound:  3-pentanone
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- diethyl sulfide + butanethiol
# Assigned id to individual compound:  diethyl sulfide
# Assigned id to individual compound:  butanethiol
# __________________________________________________________________
# Lumped compound- 2-furancarbonitrile + 3-furancarbonitrile
# Assigned id to individual compound:  2-furancarbonitrile
# Unable to assign id to inidividual compound:  3-furancarbonitrile
# __________________________________________________________________
# Lumped compound- 2-methyl pyridine + 3-methylpyridine
# Assigned id to individual compound:  2-methyl pyridine
# Assigned id to individual compound:  3-methylpyridine
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- pyridine aldehyde + methylfuronitrile + nitrosobenzene
# Assigned id to individual compound:  pyridine aldehyde
# Unable to assign id to inidividual compound:  methylfuronitrile
# Assigned id to individual compound:  nitrosobenzene
# __________________________________________________________________
# Lumped compound- dimethyl pyridine + ethylpyridine + heptylnitriles
# Unable to assign id to inidividual compound:  dimethyl pyridine
# Assigned id to individual compound:  ethylpyridine
# Unable to assign id to inidividual compound:  heptylnitriles
# __________________________________________________________________
# Lumped compound- phenol, 3-methyl+phenol, 4-methyl
# Unable to assign id to inidividual compound:  phenol, 3-methyl
# Unable to assign id to inidividual compound:  phenol, 4-methyl
# __________________________________________________________________
# Lumped compound- dihydroxy pyridine + methyl maleimide
# Unable to assign id to inidividual compound:  dihydroxy pyridine
# Unable to assign id to inidividual compound:  methyl maleimide
# __________________________________________________________________
# Lumped compound- heptanal + 2,4-dimethyl-3-pentanone + heptanone
# Assigned id to individual compound:  heptanal
# Assigned id to individual compound:  2,4-dimethyl-3-pentanone
# Unable to assign id to inidividual compound:  heptanone
# __________________________________________________________________
# Lumped compound- benzaldehyde, 2-methyl+benzaldehyde, 3-methyl
# Unable to assign id to inidividual compound:  benzaldehyde, 2-methyl
# Unable to assign id to inidividual compound:  benzaldehyde, 3-methyl
# __________________________________________________________________
# Lumped compound- 2,5-di(hydroxymethyl)furan + Methyl hydroxy dihydrofurfural
# Assigned id to individual compound:  2,5-di(hydroxymethyl)furan
# Unable to assign id to inidividual compound:  Methyl hydroxy dihydrofurfural
# __________________________________________________________________
# Lumped compound- Eugenol + isoeugenol
# Assigned id to individual compound:  Eugenol
# Assigned id to individual compound:  isoeugenol
# __________________________________________________________________
# Lumped compound- Dihydropyrrole + butane nitrile
# Assigned id to individual compound:  Dihydropyrrole
# Assigned id to individual compound:  butane nitrile
# __________________________________________________________________
# Lumped compound- Pentene + methyl butene
# Assigned id to individual compound:  Pentene
# Assigned id to individual compound:  methyl butene
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- 2-methylpentane+3-methylpentane
# Assigned id to individual compound:  2-methylpentane
# Assigned id to individual compound:  3-methylpentane
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- Ethyl benzene + m-xylene + p-xylene + o-xylene
# Assigned id to individual compound:  Ethyl benzene
# Assigned id to individual compound:  m-xylene
# Assigned id to individual compound:  p-xylene
# Assigned id to individual compound:  o-xylene
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- 2-methylphenol+anisol
# Assigned id to individual compound:  2-methylphenol
# Assigned id to individual compound:  anisol
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- 5-Methyl furfural + catechol +resorcinol
# Assigned id to individual compound:  5-Methyl furfural
# Assigned id to individual compound:  catechol
# Assigned id to individual compound:  resorcinol
# All individual ids are found in the Integrated Dataset
# __________________________________________________________________
# Lumped compound- 5-hydroxymethyl tetrahydro 2-furanone + 5-hydroxy tetrahydro 2-furfural
# Unable to assign id to inidividual compound:  5-hydroxymethyl tetrahydro 2-furanone
# Unable to assign id to inidividual compound:  5-hydroxy tetrahydro 2-furfural
# __________________________________________________________________
# Lumped compound- Indane + methyl styrenes + propenyl benzenes
# Assigned id to individual compound:  Indane
# Unable to assign id to inidividual compound:  methyl styrenes
# Unable to assign id to inidividual compound:  propenyl benzenes
# __________________________________________________________________
# Lumped compound- Isobutyl nitrate + 2-Butyl nitrate
# Assigned id to individual compound:  Isobutyl nitrate
# Assigned id to individual compound:  2-Butyl nitrate
# __________________________________________________________________
# Lumped compound- Methyl propenyl benzene + ethyl styrene
# Unable to assign id to inidividual compound:  Methyl propenyl benzene
# Assigned id to individual compound:  ethyl styrene
# __________________________________________________________________

# %%
# data sort
nmogdf=nv.sort_nmog_data(nmogdf)
igdf=nv.sort_inorganic_gas_data(int_df)
pmdf=nv.sort_particulate_matter_data(int_df)
int_df = pd.concat([igdf, nmogdf, pmdf], ignore_index=True)

# %%
efcoldf=pd.read_sql(text('select * from bkdb_info_efcol'), con=bk_db)

# %%
int_df=nv.calc_NOx_as_NO (int_df)

# %%
int_df_2, efcoldf = nv.calculate_average_lab_study(int_df, efcoldf)

# %%
int_df_3=nv.lab_data_adjust_to_field_conditions(int_df_2,efcoldf)[0]

# %%
int_df_3=nv.assign_data_count_column(int_df_3,efcoldf)

# %%
avgdf = nv.calculate_average_fire_types(int_df_3, efcoldf)
avgdf= nv.assign_fractional_contribution (avgdf)

# %%
# Compare with the Recommended EF dataset
output_db=nv.connect_db('neiva_output_db')
rdf=pd.read_sql(text('select * from Recommended_EF'), con=output_db)

avgdf=avgdf.rename(columns={'AVG_temperate_forest':'AVG_new'})
avgdf=avgdf.rename(columns={'N_temperate_forest':'N_new'})
avgdf=avgdf.rename(columns={'STD_temperate_forest':'STD_new'})
unmatch_id=avgdf[['mm','formula','compound','id']][~avgdf['id'].isin(rdf['id'])]
rdf = pd.concat([rdf,unmatch_id], ignore_index=True)
rdf=rdf.merge(avgdf[['id','AVG_new','N_new','STD_new']], on='id',how='left')
# Use nv.rounding function to format the table.
aa = rdf.applymap(lambda x: nv.rounding(x))

# %%
aa[['mm','formula','compound','AVG_temperate_forest','AVG_new','N_temperate_forest','N_new','STD_temperate_forest','STD_new' ]][rdf['id'].isin(new_df['id'])]
# Out:
#        mm formula         compound AVG_temperate_forest  AVG_new  \
# 3      28      CO  Carbon monoxide                95.95    95.95
# 10     44     CO2   Carbon dioxide              1581.13  1581.13
# 300    92    C7H8          Toluene                 0.43    17.86
# 314    94   C6H6O           Phenol                 0.35    10.51
# 1272  136  C10H16     New_compound                  nan   366.61
#
#      N_temperate_forest N_new STD_temperate_forest STD_new
# 3                    19    20                15.32   14.91
# 10                   19    20               130.25  126.78
# 300                  13    14                 0.43   65.21
# 314                  11    12                 0.26   35.18
# 1272                nan     1                  nan     nan

# %% [markdown]
# ## **6. Verify the result: An example is shown here**

# %%
# !mysql -u root -proot -e "use backend_db; delete from bkdb_info_efcol where efcol='EF_new_data_temperate_forest';"

# %%
# Input the comppund and new EF
compound = 'Toluene'
new_EF = 200

# %%
nv.compare_lab_field ('temperate forest', 'carbon monoxide','integrated ef')
# Out:
#                  Mean    Lab  Field
# 0  Carbon monoxide EF  85.15  95.95
# 1                 MCE   0.92   0.91
# 2          data count     39     14

# %%
dd=nv.select_compound ('temperate forest', compound, 'processed ef')
dd = dd.applymap(lambda x: nv.read_rounding(x))
dd
# Out:
#                          legend  \
# 0            Stockwell et al 15
# 1            Gkatzelis et al 23
# 2   Akagi_11(Yokelson et al 13)
# 3               Permar et al 21
# 4               Travis et al 23
# 5               Travis et al 23
# 6                 Koss et al 18
# 7                Hatch et al 15
# 8   Akagi_11(Yokelson et al 13)
# 9                  Liu et al 17
# 10     Akagi_11(Akagi et al 13)
# 11              Travis et al 23
# 12  Akagi_11(Yokelson et al 13)
#
#                                             fuel_type measurement_type   MCE  \
# 0                    juniper,ponderosa pine,wiregrass              lab   NaN
# 1                               temperate forest fire            field  0.90
# 2                                        organic soil            field  0.85
# 3                                   coniferous canopy            field  0.90
# 4                                               slash            field  0.89
# 5                                                pile            field  0.91
# 6   engelmann spruce,subalpine fir,loblolly pine,c...              lab   NaN
# 7                            ponderosa pine,wiregrass              lab   NaN
# 8                                   coniferous canopy            field  0.93
# 9                           temperate forest wildfire            field  0.91
# 10                        pine forest understory fire            field  0.93
# 11                                         blackwater            field  0.94
# 12                        pine forest understory fire            field  0.94
#
#       EF
# 0   1.82
# 1   0.53
# 2   0.49
# 3   0.42
# 4   0.38
# 5   0.34
# 6   0.32
# 7   0.29
# 8   0.25
# 9   0.24
# 10  0.20
# 11  0.18
# 12  0.14

# %%
# Account for lab data adjustment to field condition; Fractional contribution step will not affect Toluene EF.
new_EF = (new_EF/78.52)*95.95
# Add the new EF data with the processed ef data
dd.loc[-1,'EF']=new_EF
dd
# Out:
#                           legend  \
#  0            Stockwell et al 15
#  1            Gkatzelis et al 23
#  2   Akagi_11(Yokelson et al 13)
#  3               Permar et al 21
#  4               Travis et al 23
#  5               Travis et al 23
#  6                 Koss et al 18
#  7                Hatch et al 15
#  8   Akagi_11(Yokelson et al 13)
#  9                  Liu et al 17
#  10     Akagi_11(Akagi et al 13)
#  11              Travis et al 23
#  12  Akagi_11(Yokelson et al 13)
# -1                           NaN
#
#                                              fuel_type measurement_type   MCE  \
#  0                    juniper,ponderosa pine,wiregrass              lab   NaN
#  1                               temperate forest fire            field  0.90
#  2                                        organic soil            field  0.85
#  3                                   coniferous canopy            field  0.90
#  4                                               slash            field  0.89
#  5                                                pile            field  0.91
#  6   engelmann spruce,subalpine fir,loblolly pine,c...              lab   NaN
#  7                            ponderosa pine,wiregrass              lab   NaN
#  8                                   coniferous canopy            field  0.93
#  9                           temperate forest wildfire            field  0.91
#  10                        pine forest understory fire            field  0.93
#  11                                         blackwater            field  0.94
#  12                        pine forest understory fire            field  0.94
# -1                                                 NaN              NaN   NaN
#
#              EF
#  0     1.820000
#  1     0.530000
#  2     0.490000
#  3     0.420000
#  4     0.380000
#  5     0.340000
#  6     0.320000
#  7     0.290000
#  8     0.250000
#  9     0.240000
#  10    0.200000
#  11    0.180000
#  12    0.140000
# -1   244.396332

# %%
# Calculate Mean
nv.rounding(dd['EF'].mean())
# Out:
# '17.86'
