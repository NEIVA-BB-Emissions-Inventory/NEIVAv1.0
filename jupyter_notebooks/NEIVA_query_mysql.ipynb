# %% [markdown]
# # **Execute Query using the NEIVA Database**

# %% [markdown]
# ## **1. Setting up the NEIVA database in the Google Colab environment:**

# %%
# !pip install mysql-connector-python # Install the necessary package to connect Python with MySQL databases.
# !pip install pubchempy
# !apt-get update
# !pip install pymysql
# !apt-get -y install mysql-server    # Install the MySQL server on the Colab environment.
# !service mysql start                # With MySQL install, this starts the server.

# Setting the password. Here 'root' is used as password.

# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH 'mysql_native_password' BY 'root';FLUSH PRIVILEGES;"

# %%
# Remove the existing NEIVA repository if it exists.
# !rm -rf NEIVA
# Download the NEIVA repository from GitHub
# !git clone https://github.com/NEIVA-BB-emissions-Inventory/NEIVA.git

# %%
# Check if the repository is downloaded by listing its contents.
# !ls NEIVA

# %%
# !mysql -u root -proot -e "drop database backend_db"
# !mysql -u root -proot -e "drop database primary_db"
# !mysql -u root -proot -e "drop database raw_db"
# !mysql -u root -proot -e "drop database legacy_db"
# !mysql -u root -proot -e "drop database neiva_output_db"

# %%
# Initialize MySQL databases and import data from NEIVA SQL files.
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS backend_db"
# !mysql -u root -proot backend_db < NEIVA/data/backend_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS legacy_db"
# !mysql -u root -proot legacy_db < NEIVA/data/legacy_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS neiva_output_db"
# !mysql -u root -proot neiva_output_db < NEIVA/data/neiva_output_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS primary_db"
# !mysql -u root -proot primary_db < NEIVA/data/primary_db.sql
# !mysql -u root -proot -e "CREATE DATABASE IF NOT EXISTS raw_db"
# !mysql -u root -proot raw_db < NEIVA/data/raw_db.sql

# %% [markdown]
# ## **2. Viewing the databases and their contents using MySQL syntax:**

# %%
# !mysql -u root -proot -e "show databases";
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +--------------------+
# | Database           |
# +--------------------+
# | backend_db         |
# | information_schema |
# | legacy_db          |
# | mysql              |
# | neiva_output_db    |
# | performance_schema |
# | primary_db         |
# | raw_db             |
# | sys                |
# +--------------------+

# %%
# !mysql -u root -proot -e "use backend_db; show tables;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +---------------------------------------+
# | Tables_in_backend_db                  |
# +---------------------------------------+
# | bkdb_compound_flaming_combustion_type |
# | bkdb_correction_factor                |
# | bkdb_fc_calc_simple                   |
# | bkdb_fc_calc_specific                 |
# | bkdb_imp_comList_for_calc             |
# | bkdb_info_efcol                       |
# | bkdb_info_rdb_ldb                     |
# | bkdb_info_table_name                  |
# | bkdb_nmog_LumpCom_altName             |
# | bkdb_nmog_LumpedCom                   |
# | bkdb_nmog_MultLumCom                  |
# | bkdb_nmog_MultLumCom_slc_id           |
# | bkdb_nmog_MultLumCom_slc_id_altName   |
# | bkdb_pm_order_seq                     |
# | chem_property_h15isomers              |
# | chem_property_inchi                   |
# | chem_property_lumpCom                 |
# | chem_property_lumpCom_spec            |
# | info_efcol_processed_data             |
# | property_surrogate_info               |
# +---------------------------------------+

# %%
# !mysql -u root -proot -e "use primary_db; select * from pdb_travis23 where pollutant_category='inorganic gas';"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +---------+----------+----------------------+--------------------+------------------+------------------+---------------------+--------------------------+-------------------+------------------+-----------------------+-----------------------+------------------------+-------------------------------------------+
# | mm      | formula  | compound             | pollutant_category | EF_corn_travis23 | EF_rice_travis23 | EF_soybean_travis23 | EF_winter_wheat_travis23 | EF_slash_travis23 | EF_pile_travis23 | EF_shrubland_travis23 | EF_grassland_travis23 | EF_blackwater_travis23 | id                                        |
# +---------+----------+----------------------+--------------------+------------------+------------------+---------------------+--------------------------+-------------------+------------------+-----------------------+-----------------------+------------------------+-------------------------------------------+
# |   28.01 | CO       | Carbon Monoxide      | inorganic gas      |               65 |               85 |                  86 |                       38 |               125 |              108 |                    65 |                   113 |                     69 | InChI=1S/CO/c1-2                          |
# |   44.01 | CO2      | Carbon Dioxide       | inorganic gas      |             1412 |             1378 |                1376 |                     1461 |              1655 |             1684 |                  1586 |                  1506 |                   1719 | InChI=1S/CO2/c2-1-3                       |
# |   30.01 | NO       | Nitrogen oxide       | inorganic gas      |             0.36 |             0.28 |               0.167 |                    0.951 |             0.087 |            0.155 |                 0.005 |                 0.148 |                  0.216 | InChI=1S/NO/c1-2                          |
# | 46.0055 | NO2      | Nitrogen dioxide     | inorganic gas      |             1.83 |             1.72 |                1.27 |                     5.26 |              1.03 |             1.19 |                 0.102 |                  1.35 |                      2 | InChI=1S/NO2/c2-1-3                       |
# |   30.01 | NO       | NOx (as NO)          | inorganic gas      |             1.55 |             1.36 |               0.995 |                     4.38 |             0.758 |            0.933 |                 0.072 |                  1.03 |                   1.44 | NOx_as_NO                                 |
# |   43.03 | HNCO     | Isocyanic acid       | inorganic gas      |            0.441 |             0.69 |               0.355 |                    0.659 |             0.322 |            0.639 |                  NULL |                  1.05 |                  0.708 | InChI=1S/CHNO/c2-1-3/h2H                  |
# |  47.013 | HONO     | Nitrous acid         | inorganic gas      |            0.387 |            0.379 |               0.421 |                    0.455 |             0.311 |            0.403 |                  NULL |                 0.638 |                  0.506 | InChI=1S/HNO2/c2-1-3/h(H,2,3)             |
# |  108.01 | N2O5     | Dinitrogen pentoxide | inorganic gas      |         0.000123 |         0.000236 |                NULL |                     NULL |          0.000273 |        0.0000815 |                  NULL |              0.000418 |                  0.001 | InChI=1S/N2O5/c3-1(4)7-2(5)6              |
# |   81.46 | ClNO2    | Nitryl chloride      | inorganic gas      |         0.000159 |         0.000164 |           0.0000588 |                     NULL |         0.0000358 |         0.000275 |                  NULL |              0.000103 |               0.000189 | InChI=1S/ClNO2/c1-3(2)4                   |
# |  94.497 | C2H3O2Cl | Chloroacetic acid    | inorganic gas      |        0.0000898 |         0.000182 |           0.0000558 |                     NULL |              NULL |         0.000394 |                  NULL |              0.000267 |                   NULL | InChI=1S/C2H3ClO2/c3-1-2(4)5/h1H2,(H,4,5) |
# |  64.066 | SO2      | Sulfur dioxide       | inorganic gas      |            0.906 |            0.883 |               0.625 |                     1.36 |             0.343 |             0.53 |                 0.142 |                  1.07 |                  0.992 | InChI=1S/O2S/c1-3-2                       |
# |  34.015 | H2O2     | Hydrogen Peroxide    | inorganic gas      |            0.071 |             0.09 |               0.102 |                    0.058 |             0.077 |            0.081 |                 0.379 |                 0.131 |                  0.069 | InChI=1S/H2O2/c1-2/h1-2H                  |
# +---------+----------+----------------------+--------------------+------------------+------------------+---------------------+--------------------------+-------------------+------------------+-----------------------+-----------------------+------------------------+-------------------------------------------+

# %%
# !mysql -u root -proot -e "use primary_db; select * from pdb_trf_hodgson18;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +--------+---------+-----------------+--------------------+-----------------------+--------------------------------+---------------------------------------------+
# | mm     | formula | compound        | pollutant_category | EF_rondonia_hodgson18 | EF_tocantins_cerrado_hodgson18 | id                                          |
# +--------+---------+-----------------+--------------------+-----------------------+--------------------------------+---------------------------------------------+
# | 44.009 | CO2     | carbon dioxide  | inorganic gas      |                  1447 |                           1711 | InChI=1S/CO2/c2-1-3                         |
# |  28.01 | CO      | carbon monoxide | inorganic gas      |                   237 |                             74 | InChI=1S/CO/c1-2                            |
# | 16.043 | CH4     | methane         | methane            |                  5.17 |                           2.23 | InChI=1S/CH4/h1H4                           |
# |   NULL | NULL    | OM              | PM total           |                     8 |                           1.31 | OM                                          |
# |   NULL | NULL    | OC              | PM carbon          |                     5 |                           0.82 | OC                                          |
# |   NULL | NULL    | BC              | PM carbon          |                 0.019 |                           0.13 | BC                                          |
# |  35.45 | Cl -    | chloride ion    | PM ion             |                  0.04 |                           0.09 | InChI=1S/ClH/h1H/p-1                        |
# | 62.005 | NO3 -   | nitrate ion     | PM ion             |                 0.078 |                          0.013 | InChI=1S/NO3/c2-1(3)4/q-1                   |
# |  96.07 | SO4 2-  | sulphate ion    | PM ion             |                 0.034 |                         0.0006 | InChI=1S/H2O4S/c1-5(2,3)4/h(H2,1,2,3,4)/p-2 |
# | 18.039 | NH4 -   | ammonium ion    | PM ion             |                 0.033 |                          0.015 | InChI=1S/H3N/h1H3/p+1                       |
# +--------+---------+-----------------+--------------------+-----------------------+--------------------------------+---------------------------------------------+

# %%
# !mysql -u root -proot -e "use primary_db; select * from pdb_p_stockwell16;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +---------+---------+-------------------------------+---------------------+---------------------+---------------------------------------------------------------+
# | mm      | formula | compound                      | pollutant_category  | EF_peat_stockwell16 | id                                                            |
# +---------+---------+-------------------------------+---------------------+---------------------+---------------------------------------------------------------+
# |  44.009 | CO2     | carbon dioxide                | inorganic gas       |           1564.1813 | InChI=1S/CO2/c2-1-3                                           |
# |   28.01 | CO      | carbon monoxide               | inorganic gas       |            290.5111 | InChI=1S/CO/c1-2                                              |
# |  16.043 | CH4     | methane                       | methane             |              9.5078 | InChI=1S/CH4/h1H4                                             |
# |   2.016 | H2      | dihydrogen                    | inorganic gas       |               1.217 | InChI=1S/H2/h1H                                               |
# |   26.04 | C2H2    | acetylene                     | NMOC_g              |              0.1213 | InChI=1S/C2H2/c1-2/h1-2H                                      |
# |   28.05 | C2H4    | ethylene                      | NMOC_g              |               0.961 | InChI=1S/C2H4/c1-2/h1-2H2                                     |
# |   42.08 | C3H6    | propylene                     | NMOC_g              |              1.0668 | InChI=1S/C3H6/c1-3-2/h3H,1H2,2H3                              |
# |  30.026 | HCHO    | formaldehyde                  | NMOC_g              |              0.8667 | InChI=1S/CH2O/c1-2/h1H2                                       |
# |  32.042 | CH3OH   | methanol                      | NMOC_g              |              2.1353 | InChI=1S/CH4O/c1-2/h2H,1H3                                    |
# |  46.025 | HCOOH   | formic acid                   | NMOC_g              |                0.18 | InChI=1S/CH2O2/c2-1-3/h1H,(H,2,3)                             |
# |   60.05 | CH3COOH | acetic acid                   | NMOC_g              |               3.889 | InChI=1S/C2H4O2/c1-2(3)4/h1H3,(H,3,4)                         |
# |   60.05 | C2H4O2  | glycolaldehyde                | NMOC_g              |              0.1077 | InChI=1S/C2H4O2/c3-1-2-4/h1,4H,2H2                            |
# |   68.07 | C4H4O   | furan                         | NMOC_g              |              0.7364 | InChI=1S/C4H4O/c1-2-4-5-3-1/h1-4H                             |
# |   74.08 | C3H6O2  | hydroxyacetone                | NMOC_g              |              0.8603 | InChI=1S/C3H6O2/c1-3(5)2-4/h4H,2H2,1H3                        |
# |   94.11 | C6H5OH  | phenol                        | NMOC_g              |              0.4188 | InChI=1S/C6H6O/c7-6-4-2-1-3-5-6/h1-5,7H                       |
# |   54.09 | C4H6    | 1,3-butadiene                 | NMOC_g              |              0.1893 | InChI=1S/C4H6/c1-3-4-2/h3-4H,1-2H2                            |
# |   68.12 | C5H8    | isoprene                      | NMOC_g              |              0.0528 | InChI=1S/C5H8/c1-4-5(2)3/h4H,1-2H2,3H3                        |
# |  17.031 | NH3     | ammonia                       | inorganic gas       |              2.8646 | InChI=1S/H3N/h1H3                                             |
# |  27.025 | HCN     | hydrogen cyanide              | NMOC_g              |              5.7486 | InChI=1S/CHN/c1-2/h1H                                         |
# |  47.014 | HONO    | nitrous acid                  | inorganic gas       |               0.208 | InChI=1S/HNO2/c2-1-3/h(H,2,3)                                 |
# |   36.46 | HCl     | hydrogen chloride             | inorganic gas       |              0.0346 | InChI=1S/ClH/h1H                                              |
# |  30.006 | NO      | nitric oxide                  | inorganic gas       |              0.3073 | InChI=1S/NO/c1-2                                              |
# |   60.08 | COS     | carbonyl sulfide              | inorganic gas       |              0.1104 | InChI=1S/COS/c2-1-3                                           |
# |   62.14 | C2H6S   | dms                           | NMOC_g              |              0.0028 | InChI=1S/C2H6S/c1-3-2/h1-2H3                                  |
# |   50.49 | CH3Cl   | chloromethane                 | NMOC_g              |              0.1466 | InChI=1S/CH3Cl/c1-2/h1H3                                      |
# |   94.94 | CH3Br   | bromomethane                  | NMOC_g              |              0.0101 | InChI=1S/CH3Br/c1-2/h1H3                                      |
# | 141.939 | CH3I    | methyl iodide                 | NMOC_g              |              0.0125 | InChI=1S/CH3I/c1-2/h1H3                                       |
# |  173.83 | CH2Br2  | dibromomethane                | NMOC_g              |              0.0001 | InChI=1S/CH2Br2/c2-1-3/h1H2                                   |
# |   30.07 | C2H6    | ethane                        | NMOC_g              |              1.5224 | InChI=1S/C2H6/c1-2/h1-2H3                                     |
# |    44.1 | C3H8    | propane                       | NMOC_g              |              0.9888 | InChI=1S/C3H8/c1-3-2/h3H2,1-2H3                               |
# |   58.12 | C4H10   | i-butane                      | NMOC_g              |              0.0911 | InChI=1S/C4H10/c1-4(2)3/h4H,1-3H3                             |
# |   58.12 | C4H10   | n-butane                      | NMOC_g              |               0.321 | InChI=1S/C4H10/c1-3-4-2/h3-4H2,1-2H3                          |
# |   56.11 | C4H8    | 1-butene                      | NMOC_g              |              0.1816 | InChI=1S/C4H8/c1-3-4-2/h3H,1,4H2,2H3                          |
# |   56.11 | C4H8    | i-butene                      | NMOC_g              |              0.3106 | InChI=1S/C4H8/c1-4(2)3/h1H2,2-3H3                             |
# |   56.11 | C4H8    | trans-2-butene                | NMOC_g              |              0.0775 | InChI=1S/C4H8/c1-3-4-2/h3-4H,1-2H3/b4-3+                      |
# |   56.11 | C4H8    | cis-2-butene                  | NMOC_g              |              0.0615 | InChI=1S/C4H8/c1-3-4-2/h3-4H,1-2H3/b4-3-                      |
# |   72.15 | C5H12   | iso-pentane                   | NMOC_g              |              0.1232 | InChI=1S/C5H12/c1-4-5(2)3/h5H,4H2,1-3H3                       |
# |   72.15 | C5H12   | n-pentane                     | NMOC_g              |               0.243 | InChI=1S/C5H12/c1-3-5-4-2/h3-5H2,1-2H3                        |
# |   40.06 | C3H4    | 1,2-propadiene                | NMOC_g              |              0.0018 | InChI=1S/C3H4/c1-3-2/h1-2H2                                   |
# |   40.06 | C3H4    | propyne                       | NMOC_g              |              0.0056 | InChI=1S/C3H4/c1-3-2/h1H,2H3                                  |
# |   54.09 | C4H6    | 1-butyne                      | NMOC_g              |               0.002 | InChI=1S/C4H6/c1-3-4-2/h1H,4H2,2H3                            |
# |   54.09 | C4H6    | 2-butyne                      | NMOC_g              |              0.0011 | InChI=1S/C4H6/c1-3-4-2/h1-2H3                                 |
# |   50.06 | C4H2    | 1,3-butadyne                  | NMOC_g              |              0.0003 | InChI=1S/C4H2/c1-3-4-2/h1-2H                                  |
# |   54.09 | C4H6    | 1,2-butadiene                 | NMOC_g              |              0.0006 | InChI=1S/C4H6/c1-3-4-2/h4H,1H2,2H3                            |
# |   70.13 | C5H10   | 1-pentene                     | NMOC_g              |              0.1098 | InChI=1S/C5H10/c1-3-5-4-2/h3H,1,4-5H2,2H3                     |
# |   70.13 | C5H10   | trans-2-pentene               | NMOC_g              |              0.0397 | InChI=1S/C5H10/c1-3-5-4-2/h3,5H,4H2,1-2H3/b5-3+               |
# |   70.13 | C5H10   | cis-2-pentene                 | NMOC_g              |              0.0224 | InChI=1S/C5H10/c1-3-5-4-2/h3,5H,4H2,1-2H3/b5-3-               |
# |   70.13 | C5H10   | 3-methyl-1-butene             | NMOC_g              |              0.0303 | InChI=1S/C5H10/c1-4-5(2)3/h4-5H,1H2,2-3H3                     |
# |   70.13 | C5H10   | 2-methyl-1-butene             | NMOC_g              |              0.0299 | InChI=1S/C5H10/c1-4-5(2)3/h2,4H2,1,3H3                        |
# |   70.13 | C5H10   | 2-methyl-2-butene             | NMOC_g              |              0.0647 | InChI=1S/C5H10/c1-4-5(2)3/h4H,1-3H3                           |
# |   84.16 | C6H12   | 2-methyl-1-pentene            | NMOC_g              |              0.1094 | InChI=1S/C6H12/c1-4-5-6(2)3/h2,4-5H2,1,3H3                    |
# |   68.12 | C5H8    | 1,3-pentadiene                | NMOC_g              |              0.0198 | InChI=1S/C5H8/c1-3-5-4-2/h3-5H,1H2,2H3/b5-4+                  |
# |    66.1 | C5H6    | 1,3-cyclopentadiene           | NMOC_g              |                0.01 | InChI=1S/C5H6/c1-2-4-5-3-1/h1-4H,5H2                          |
# |   68.12 | C5H8    | cyclopentene                  | NMOC_g              |              0.0246 | InChI=1S/C5H8/c1-2-4-5-3-1/h1-2H,3-5H2                        |
# |   98.19 | C7H14   | 1-heptene                     | NMOC_g              |               0.079 | InChI=1S/C7H14/c1-3-5-7-6-4-2/h3H,1,4-7H2,2H3                 |
# |  112.21 | C8H16   | 1-octene                      | NMOC_g              |              0.0652 | InChI=1S/C8H16/c1-3-5-7-8-6-4-2/h3H,1,4-8H2,2H3               |
# |  140.27 | C10H20  | 1-decene                      | NMOC_g              |              0.0498 | InChI=1S/C10H20/c1-3-5-7-9-10-8-6-4-2/h3H,1,4-10H2,2H3        |
# |   86.18 | C6H14   | n-hexane                      | NMOC_g              |              0.1425 | InChI=1S/C6H14/c1-3-5-6-4-2/h3-6H2,1-2H3                      |
# |   100.2 | C7H16   | n-heptane                     | NMOC_g              |               0.112 | InChI=1S/C7H16/c1-3-5-7-6-4-2/h3-7H2,1-2H3                    |
# |  114.23 | C8H18   | n-octane                      | NMOC_g              |               0.098 | InChI=1S/C8H18/c1-3-5-7-8-6-4-2/h3-8H2,1-2H3                  |
# |  128.25 | C9H20   | n-nonane                      | NMOC_g              |              0.0895 | InChI=1S/C9H20/c1-3-5-7-9-8-6-4-2/h3-9H2,1-2H3                |
# |  142.28 | C10H22  | n-decane                      | NMOC_g              |              0.0744 | InChI=1S/C10H22/c1-3-5-7-9-10-8-6-4-2/h3-10H2,1-2H3           |
# |   86.18 | C6H14   | 2,3-dimethylbutane            | NMOC_g              |              0.0053 | InChI=1S/C6H14/c1-5(2)6(3)4/h5-6H,1-4H3                       |
# |   86.18 | C6H14   | 2-methylpentane               | NMOC_g              |              0.0397 | InChI=1S/C6H14/c1-4-5-6(2)3/h6H,4-5H2,1-3H3                   |
# |   86.18 | C6H14   | 3-methylpentane               | NMOC_g              |              0.0093 | InChI=1S/C6H14/c1-4-6(3)5-2/h6H,4-5H2,1-3H3                   |
# |   78.11 | C6H6    | benzene                       | NMOC_g              |               0.954 | InChI=1S/C6H6/c1-2-4-6-5-3-1/h1-6H                            |
# |   92.14 | C7H8    | toluene                       | NMOC_g              |              0.3701 | InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h2-6H,1H3                      |
# |  106.16 | C8H10   | ethylbenzene                  | NMOC_g              |              0.0417 | InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3               |
# |  106.16 | C8H10   | m/p-xylene                    | NMOC_g              |              0.1219 | 106.078250319_C8H10                                           |
# |  106.16 | C8H10   | o-xylene                      | NMOC_g              |              0.1032 | InChI=1S/C8H10/c1-7-5-3-4-6-8(7)2/h3-6H,1-2H3                 |
# |  104.15 | C8H8    | styrene                       | NMOC_g              |              0.0271 | InChI=1S/C8H8/c1-2-8-6-4-3-5-7-8/h2-7H,1H2                    |
# |  120.19 | C9H12   | i-propylbenzene               | NMOC_g              |              0.0053 | InChI=1S/C9H12/c1-8(2)9-6-4-3-5-7-9/h3-8H,1-2H3               |
# |  120.19 | C9H12   | n-propylbenzene               | NMOC_g              |              0.0118 | InChI=1S/C9H12/c1-2-6-9-7-4-3-5-8-9/h3-5,7-8H,2,6H2,1H3       |
# |  120.19 | C9H12   | 3-ethyltoluene                | NMOC_g              |               0.027 | InChI=1S/C9H12/c1-3-9-6-4-5-8(2)7-9/h4-7H,3H2,1-2H3           |
# |  120.19 | C9H12   | 4-ethyltoluene                | NMOC_g              |              0.0235 | InChI=1S/C9H12/c1-3-9-6-4-8(2)5-7-9/h4-7H,3H2,1-2H3           |
# |  120.19 | C9H12   | 2-ethyltoluene                | NMOC_g              |              0.0416 | InChI=1S/C9H12/c1-3-9-7-5-4-6-8(9)2/h4-7H,3H2,1-2H3           |
# |  120.19 | C9H12   | 1,3,5-trimethylbenzene        | NMOC_g              |              0.0108 | InChI=1S/C9H12/c1-7-4-8(2)6-9(3)5-7/h4-6H,1-3H3               |
# |  120.19 | C9H12   | 1,2,4-trimethylbenzene        | NMOC_g              |              0.0696 | InChI=1S/C9H12/c1-7-4-5-8(2)9(3)6-7/h4-6H,1-3H3               |
# |  120.19 | C9H12   | 1,2,3-trimethylbenzene        | NMOC_g              |              0.0639 | InChI=1S/C9H12/c1-7-5-4-6-8(2)9(7)3/h4-6H,1-3H3               |
# |  136.23 | C10H16  | alpha-pinene                  | NMOC_g              |               0.003 | InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h4,8-9H,5-6H2,1-3H3 |
# |  136.23 | C10H16  | beta-pinene                   | NMOC_g              |              0.0017 | InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h8-9H,1,4-6H2,2-3H3 |
# |    82.1 | C5H6O   | 2-methylfuran                 | NMOC_g              |              0.1213 | InChI=1S/C5H6O/c1-5-3-2-4-6-5/h2-4H,1H3                       |
# |   61.04 | CH3NO2  | nitromethane                  | NMOC_g              |              0.0601 | InChI=1S/CH3NO2/c1-2(3)4/h1H3                                 |
# |   44.05 | C2H4O   | acetaldehyde                  | NMOC_g              |              0.6972 | InChI=1S/C2H4O/c1-2-3/h2H,1H3                                 |
# |   72.11 | C4H8O   | butanal                       | NMOC_g              |              0.0238 | InChI=1S/C4H8O/c1-2-3-4-5/h4H,2-3H2,1H3                       |
# |   96.08 | C5H4O2  | furfural                      | NMOC_g              |              0.1235 | InChI=1S/C5H4O2/c6-4-5-2-1-3-7-5/h1-4H                        |
# |   58.08 | C3H6O   | acetone                       | NMOC_g              |              0.6906 | InChI=1S/C3H6O/c1-3(2)4/h1-2H3                                |
# |   72.11 | C4H8O   | butanone                      | NMOC_g              |               0.136 | InChI=1S/C4H8O/c1-3-4(2)5/h3H2,1-2H3                          |
# |   70.09 | C4H6O   | methyl vinyl ketone           | NMOC_g              |              0.0569 | InChI=1S/C4H6O/c1-3-4(2)5/h3H,1H2,2H3                         |
# |    NULL | NULL    | EF BC (g kg1)                 | PM carbon           |              0.0055 | BC                                                            |
# |    NULL | NULL    | EF B abs 870 (m2 kg 1)        | PM optical property |              0.0261 | Babs_870                                                      |
# |    NULL | NULL    | EF B scat 870 (m 2 kg 1)      | PM optical property |                18.3 | Bscat_870                                                     |
# |    NULL | NULL    | EF Babs 405 (m2 kg1)          | PM optical property |                1.35 | Babs_405                                                      |
# |    NULL | NULL    | EF B 405 (m2 kg1scat )        | PM optical property |                50.6 | B_405                                                         |
# |    NULL | NULL    | EF Babs 405 just BrC (m2 kg1) | PM optical property |                 1.3 | Babs_405_Br                                                   |
# |    NULL | NULL    | EF Babs 405 just BC (m2 kg1)  | PM optical property |               0.054 | Babs_405_BC                                                   |
# |    NULL | NULL    | SSA 870 nm                    | PM optical property |               0.998 | SSA_870                                                       |
# |    NULL | NULL    | SSA 405 nm                    | PM optical property |               0.974 | SSA_405                                                       |
# |    NULL | NULL    | AAE                           | PM optical property |                4.97 | AAE                                                           |
# +---------+---------+-------------------------------+---------------------+---------------------+---------------------------------------------------------------+

# %%
# !mysql -u root -proot -e "use neiva_output_db; show tables;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +---------------------------+
# | Tables_in_neiva_output_db |
# +---------------------------+
# | Integrated_EF             |
# | Processed_EF              |
# | Property_Surrogate        |
# | Recommended_EF            |
# +---------------------------+

# %%
# !mysql -u root -proot -e "use neiva_output_db; select * from Integrated_EF where pollutant_category='inorganic gas';"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +-------+----------+----------------------------+--------------------+----------------------------+------------------------------------+-------------------------+-------------------------+---------------------+------------------------+-----------------------+--------------------------+----------------------+----------------------------------+----------------------------------+-----------------------+----------------------+--------------------------+---------------------+-------------------+--------------------------------+------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------+------------------------------------------+-----------------------------------+----------------------------------+----------------------------------+----------------------------------+------------------------------------+--------------------------------------------+------------------------------+----------------------------------------+---------------------------------------+-------------------------------------+--------------------------------------+---------------------------------------------+----------------------------------------------+----------------------------------------------+-------------------------------------------+------------------------------------------+--------------------------------------------+------------------------------------------+----------------------------------------+------------------------------------+------------------------------------------------+------------------------+--------------------+----------------------------------------+---------------------------------------+------------------------------------------+--------------------------------------+-------------------------------------------+--------------------------------------------+------------------------------------------+---------------------------------------+-------------------------------------------+---------------------------------+---------------------------------+-----------------------------------+-----------------------------------------------------------+---------------------------------------------------------+---------------------------------------------------+----------------------------------------+----------------------------+-------------------------------+-------------------------------+------------------------------+---------------------------+---------------------------+-----------------------------------------------+--------------------------------------------+----------------------------------------------+-------------------------------------------+-------------------------------------------+-----------------------------------------+------------------------------------+----------------------------------------+---------------------------+--------------------------------------------------------+-----------------------------------------------------+--------------------------------------------------+-----------------------------------------------+--------------------------------------------+---------------------------+------------------------------+------------------------+-------------------------+-----------------------------+------------------------------+-----------------------------------------+----------------------------------------+------------------------------------------+----------------------------+--------------------------+----------------------------+-------------------------+----------------------+--------------------------+-------------------------------+--------------------------------+---------------------------+-------------------------------------+--------------------------------------------+------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------+-------------------------------------- ...
# | mm    | formula  | compound                   | pollutant_category | EF_engelmann_spruce_koss18 | EF_manzanita_uncontaminated_koss18 | EF_subalpine_fir_koss18 | EF_loblolly_pine_koss18 | EF_ceanothus_koss18 | EF_jeffrey_pine_koss18 | EF_peat_koss18        | EF_ponderosa_pine_koss18 | EF_rice_straw_koss18 | EF_manzanita_contaminated_koss18 | EF_chamise_uncontaminated_koss18 | EF_douglas_fir_koss18 | EF_bear_grass_koss18 | EF_lodgepole_pine_koss18 | EF_sagebrush_koss18 | EF_juniper_koss18 | EF_chamise_contaminated_koss18 | EF_dung_koss18         | id                                        | EF_akagi11_boreal_organic_soil_bertschi03 | EF_akagi11_boreal_organic_soil_yokelson97 | EF_akagi11_woodydowndead_bertschi03 | EF_akagi11_boreal_alaskan_duff_burling10 | EF_akagi11_boreal_peat_yokelson97 | EF_akagi11_boreal_forest_goode00 | EF_akagi11_boreal_forest_nance93 | EF_akagi11_boreal_forest_radke91 | EF_akagi11_boreal_forest_simpson11 | EF_akagi11_semi_arid_shrublands_yokelson13 | EF_akagi11_chaparral_radke91 | EF_akagi11_charcoal_burning_bertschi03 | EF_akagi11_charcoal_burning_brocard98 | EF_akagi11_charcoal_burning_smith00 | EF_akagi11_charcoal_burning_kituyi01 | EF_akagi11_charcoal_making_kilns_bertschi03 | EF_akagi11_charcoal_making_kilns_christian10 | EF_akagi11_charcoal_making_kilns_christian07 | EF_akagi11_charcoal_making_kilns_lacaux94 | EF_akagi11_charcoal_making_kilns_smith99 | EF_akagi11_charcoal_making_kilns_pennise01 | EF_akagi11_patsari_cookstove_christian10 | EF_akagi11_patsari_cookstove_johnson08 | EF_akagi11_crop_residue_yokelson11 | EF_akagi11_crop_residue_rice_straw_christian03 | EF_akagi11_christian07 | EF_akagi11_keene06 | EF_akagi11_garbage_burning_christian10 | EF_akagi11_garbage_burning_yokelson11 | EF_akagi11_garbage_burning_AP_42_USEPA95 | EF_akagi11_garbage_burning_lemieux00 | EF_akagi11_open_cooking_africa_bertschi03 | EF_akagi11_open_cooking_mexico_christian10 | EF_akagi11_open_cooking_africa_brocard96 | EF_akagi11_open_cooking_india_smith00 | EF_akagi11_open_cooking_hondurasi_roden06 | EF_akagi11_open_cooking_roden09 | EF_akagi11_open_cooking_zhang00 | EF_akagi11_open_cooking_johnson08 | EF_akagi11_pasture_maintenance_airborne_1_fire_yokelson11 | EF_akagi11_pasture_maintenance_airborne_6_fires_ferek98 | EF_akagi11_pasture_maintenance_ground_christian07 | EF_akagi11_indonesian_peat_christian03 | EF_akagi11_peat_yokelson97 | EF_akagi11_africa_stockwell15 | EF_akagi11_africa_christian03 | EF_akagi11_africa_yokelson03 | EF_akagi11_africa_sinha03 | EF_akagi11_brazil_ferek98 | EF_akagi11_mexico_early_dry_season_yokelson11 | EF_akagi11_imperata_cylindrica_christian03 | EF_akagi11_pine_forest_understory_yokelson13 | EF_akagi11_pine_oak_understory_yokelson11 | EF_akagi11_pine_forest_understory_akagi13 | EF_akagi11_coniferous_canopy_yokelson13 | EF_akagi11_organic_soil_yokelson13 | EF_akagi11_temperate_wildlfire_radke91 | EF_akagi11_debris_radke91 | EF_akagi11_tropical_evergreen_deforestation_yokelson08 | EF_akagi11_tropical_evergreen_deforestation_ferek98 | EF_akagi11_tropical_dry_deforestation_yokelson11 | EF_akagi11_tropical_dry_deforestation_ferek98 | EF_akagi11_tropical_dry_understory_sinha04 | EF_boreal_forest_hayden22 | EF_wood_three_stone_coffey17 | EF_wood_gyapa_coffey17 | EF_wood_philip_coffey17 | EF_charcoal_philip_coffey17 | EF_charcoal_coalpot_coffey17 | EF_kentucky_bluegrass_aerostat_holder17 | EF_kentucky_blue_grass_ground_holder17 | EF_kentucky_blue_grass_airplane_holder17 | EF_wheat_aerostat_holder17 | EF_wheat_ground_holder17 | EF_wheat_airplane_holder17 | EF_rice_residue_lasko18 | EF_cropresidue_liu16 | EF_dung_chulha_fleming18 | EF_brushwood_chulha_fleming18 | EF_mixed_fuel_chulha_fleming18 | EF_dung_angithi_fleming18 | EF_garbage_burning_mixed_yokelson13 | EF_1_pot_traditional_mudstove_dung_goetz18 | EF_1_pot_traditional_mudstove_hardwood_goetz18 | EF_1_pot_traditional_mudstove_sticks_twings_goetz18 | EF_2_pot_traditional_mudstove_dung_hardwood_goetz18 | EF_crop_residue_mixed_residue_goetz18 ...
# +-------+----------+----------------------------+--------------------+----------------------------+------------------------------------+-------------------------+-------------------------+---------------------+------------------------+-----------------------+--------------------------+----------------------+----------------------------------+----------------------------------+-----------------------+----------------------+--------------------------+---------------------+-------------------+--------------------------------+------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------+------------------------------------------+-----------------------------------+----------------------------------+----------------------------------+----------------------------------+------------------------------------+--------------------------------------------+------------------------------+----------------------------------------+---------------------------------------+-------------------------------------+--------------------------------------+---------------------------------------------+----------------------------------------------+----------------------------------------------+-------------------------------------------+------------------------------------------+--------------------------------------------+------------------------------------------+----------------------------------------+------------------------------------+------------------------------------------------+------------------------+--------------------+----------------------------------------+---------------------------------------+------------------------------------------+--------------------------------------+-------------------------------------------+--------------------------------------------+------------------------------------------+---------------------------------------+-------------------------------------------+---------------------------------+---------------------------------+-----------------------------------+-----------------------------------------------------------+---------------------------------------------------------+---------------------------------------------------+----------------------------------------+----------------------------+-------------------------------+-------------------------------+------------------------------+---------------------------+---------------------------+-----------------------------------------------+--------------------------------------------+----------------------------------------------+-------------------------------------------+-------------------------------------------+-----------------------------------------+------------------------------------+----------------------------------------+---------------------------+--------------------------------------------------------+-----------------------------------------------------+--------------------------------------------------+-----------------------------------------------+--------------------------------------------+---------------------------+------------------------------+------------------------+-------------------------+-----------------------------+------------------------------+-----------------------------------------+----------------------------------------+------------------------------------------+----------------------------+--------------------------+----------------------------+-------------------------+----------------------+--------------------------+-------------------------------+--------------------------------+---------------------------+-------------------------------------+--------------------------------------------+------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------+-------------------------------------- ...
# |     2 | H2       | hydrogen                   | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | InChI=1S/H2/h1H                           |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                       NULL |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                              2.072 |                                           NULL |                   NULL |               NULL |                                   NULL |                                 0.091 |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                           1.7 |                                       NULL |                                         NULL |                                      2.03 |                                      NULL |                                    NULL |                               NULL |                                   NULL |                      NULL |                                                    3.8 |                                                NULL |                                             2.91 |                                          NULL |                                       NULL |                      NULL |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    17 | NH3      | ammonia                    | inorganic gas      |                1.570759752 |                         0.43112739 |                  1.4925 |                  0.3994 |              1.0744 |              1.3701675 |            1.63765962 |                   0.6895 |           0.28825276 |               0.5416654999999999 |                           0.4945 |                0.4892 |   1.1591323599999999 |                    0.678 |          0.72006558 |            0.6525 |                         0.3407 |             2.65128184 | InChI=1S/H3N/h1H3                         |                                      5.98 |                                      4.91 |                                1.36 |                                     3.41 |                              8.76 |                             0.93 |                             0.64 |                              0.1 |                               NULL |                                        1.5 |                          0.9 |                                   0.79 |                                  NULL |                                NULL |                                 NULL |                                        1.33 |                                         0.43 |                                         33.5 |                                       0.3 |                                     NULL |                                       NULL |                                     0.03 |                                   NULL |                 1.4080000000000001 |                                            4.1 |                   5.55 |               3.54 |                                   1.12 |                                 0.768 |                                     NULL |                                 NULL |                                      1.29 |                                       0.44 |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                     1.364 |                                                    NULL |                                              1.64 |                                  19.92 |                       8.76 |                        0.6887 |                          NULL |                         0.28 |                      NULL |                      NULL |                                          0.57 |                                        0.7 |                                        0.499 |                                      0.54 |                                      0.11 |                                   0.936 |                               2.67 |                                    1.3 |                      NULL |                                                    1.1 |                                                NULL |                                             2.48 |                                          NULL |                                        0.4 |                      0.63 |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    28 | CO       | carbon monoxide            | inorganic gas      |                    69.4181 |                            40.6194 |                 72.8033 |                 87.4088 |             64.3124 |               134.8154 |              217.8979 |                  78.5251 |              42.9901 |                          39.5609 |                          55.9302 |               65.8696 |             104.1998 |                  70.5197 |             83.7834 |           76.4334 |                        52.7307 |                84.2355 | InChI=1S/CO/c1-2                          |                                       143 |                                       137 |                               131.7 |                                      162 |                               209 |                             91.4 |                               81 |                              101 |                                113 |                                       73.8 |                           61 |                                    134 |                                   225 |                                 275 |                                122.3 |                                         345 |                                        303.2 |                                       214.72 |                                       250 |                                      226 |                                        223 |                                     35.2 |                                   48.1 |                  68.44800000000001 |                                          179.9 |                    104 |                106 |                                   45.3 |                                 26.09 |                                       42 |                                 NULL |                                        96 |                                       58.4 |                                       70 |                                    62 |                                       121 |                            97.5 |                            65.3 |                                49 |                                                    112.08 |                                                    65.3 |                                               229 |                                  210.3 |                        209 |                          NULL |                          NULL |                         71.5 |                        68 |                      43.9 |                                          79.3 |                                       51.6 |                                         72.2 |                                       103 |                                        79 |                                    85.3 |                                129 |                                   97.5 |                        83 |                                                  107.8 |                                                 105 |                                            87.13 |                                          91.4 |                                         73 |                       116 |                           70 |                     58 |                      45 |                          92 |                          187 |                                 44.0933 |                                59.1333 |                                     64.1 |                    47.1867 |                    42.29 |                         37 |                    NULL |                 64.5 |                     97.7 |                            53 |                           74.8 |                       125 |                             28.7472 |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    30 | NO       | nitric oxide               | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | InChI=1S/NO/c1-2                          |                                      NULL |                                      NULL |                                NULL |                                    0.738 |                              NULL |                             1.54 |                             NULL |                             NULL |                               0.29 |                                      0.771 |                         NULL |                                  1.163 |                                  NULL |                                NULL |                                 3.34 |                                        0.45 |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                      0.057 |                                     NULL |                                   NULL |                 1.6480000000000001 |                                           0.62 |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      1.72 |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    0.34 |                                               0.3 |                                      1 |                       NULL |                         2.931 |                          NULL |                         NULL |                      NULL |                      0.34 |                                          4.22 |                                       1.13 |                                         0.88 |                                       1.6 |                                      0.32 |                                    1.74 |                              0.559 |                                   NULL |                      NULL |                                                   NULL |                                                0.25 |                                             2.31 |                                          0.14 |                                       NULL |                     0.016 |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                0.251 |                     NULL |                          NULL |                           NULL |                      NULL |                              0.4209 |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# | 33.03 | NULL     | nitrogen oxides(NOx as NO) | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | NOx_as_NO                                 |                                      NULL |                                      NULL |                                NULL |                                     0.89 |                              NULL |                             NULL |                             1.03 |                             0.73 |                              0.962 |                                       2.18 |                         5.11 |                                  1.409 |                                  NULL |                                NULL |                                 NULL |                                        0.45 |                                         NULL |                                         NULL |                                      0.15 |                                     NULL |                                      0.063 |                                     NULL |                                   NULL |                 2.9120000000000004 |                                           0.62 |                   NULL |                0.5 |                                   NULL |                                 4.477 |                                        3 |                                 NULL |                                      2.04 |                                       NULL |                                     1.48 |                                  NULL |                                      NULL |                            NULL |                            0.75 |                              NULL |                                                     0.606 |                                                    1.11 |                                              0.33 |                                   NULL |                       NULL |                          NULL |                          NULL |                         3.37 |                      NULL |                       2.3 |                                          6.09 |                                       NULL |                                         2.55 |                                      3.66 |                                      1.31 |                                    NULL |                               NULL |                                   1.32 |                      NULL |                                                    1.7 |                                                1.18 |                                             4.63 |                                          1.74 |                                        3.5 |                      0.17 |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    34 | H2S      | Hydrogen sulfide           | inorganic gas      |                0.037770936 |                          0.0047935 |                  0.0964 |                  0.0106 |              0.0104 |   0.045337499999999996 |   0.25420013999999996 |                   0.0136 | 0.015179519999999998 |                        0.0047935 |                           0.0033 |                0.0157 |           0.03492246 |                   0.0145 |          0.01076248 |            0.0159 |                         0.0027 |             0.15514332 | InChI=1S/H2S/h1H2                         |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                       NULL |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                               NULL |                                           NULL |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                          NULL |                                       NULL |                                         NULL |                                      NULL |                                      NULL |                                    NULL |                               NULL |                                   NULL |                      NULL |                                                   NULL |                                                NULL |                                             NULL |                                          NULL |                                       NULL |                      NULL |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    34 | H2O2     | Hydrogen peroxide          | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | InChI=1S/H2O2/c1-2/h1-2H                  |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                       NULL |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                               NULL |                                           NULL |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                          NULL |                                       NULL |                                         NULL |                                      NULL |                                      NULL |                                    NULL |                               NULL |                                   NULL |                      NULL |                                                   NULL |                                                NULL |                                             NULL |                                          NULL |                                       NULL |                      NULL |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |    43 | CHNO     | Isocyanic acid             | inorganic gas      |                 0.40847516 |                         0.25261745 |                  0.5979 |                  0.1883 |              0.6056 |     0.5214300000000001 |            0.57402972 |                   0.6192 |           0.15045118 |              0.25932835000000004 |                           0.5619 |                0.4713 |   1.1244848799999998 |                   0.5741 |          1.25262278 |            0.7579 |                         0.4102 |             0.70469344 | InChI=1S/CHNO/c2-1-3/h2H                  |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                     0.0815 |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                               NULL |                                           NULL |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                          NULL |                                       NULL |                                       0.0905 |                                      NULL |                                      NULL |                                   0.168 |                              0.271 |                                   NULL |                      NULL |                                                   NULL |                                                NULL |                                             NULL |                                          NULL |                                       NULL |                     0.083 |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                              0.0711 |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# ...
# |   108 | N2O5     | Dinitrogen pentoxide       | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | InChI=1S/N2O5/c3-1(4)7-2(5)6              |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                       NULL |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                               NULL |                                           NULL |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                          NULL |                                       NULL |                                         NULL |                                      NULL |                                      NULL |                                    NULL |                               NULL |                                   NULL |                      NULL |                                                   NULL |                                                NULL |                                             NULL |                                          NULL |                                       NULL |                      NULL |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# |   201 | Hg       | gaseous elemental mercury  | inorganic gas      |                       NULL |                               NULL |                    NULL |                    NULL |                NULL |                   NULL |                  NULL |                     NULL |                 NULL |                             NULL |                             NULL |                  NULL |                 NULL |                     NULL |                NULL |              NULL |                           NULL |                   NULL | InChI=1S/Hg                               |                                      NULL |                                      NULL |                                NULL |                                     NULL |                              NULL |                             NULL |                             NULL |                             NULL |                               NULL |                                       NULL |                         NULL |                                   NULL |                                  NULL |                                NULL |                                 NULL |                                        NULL |                                         NULL |                                         NULL |                                      NULL |                                     NULL |                                       NULL |                                     NULL |                                   NULL |                               NULL |                                           NULL |                   NULL |               NULL |                                   NULL |                                  NULL |                                     NULL |                                 NULL |                                      NULL |                                       NULL |                                     NULL |                                  NULL |                                      NULL |                            NULL |                            NULL |                              NULL |                                                      NULL |                                                    NULL |                                              NULL |                                   NULL |                       NULL |                          NULL |                          NULL |                         NULL |                      NULL |                      NULL |                                          NULL |                                       NULL |                                         NULL |                                      NULL |                                      NULL |                                    NULL |                               NULL |                                   NULL |                      NULL |                                                   NULL |                                                NULL |                                             NULL |                                          NULL |                                       NULL |                  0.000087 |                         NULL |                   NULL |                    NULL |                        NULL |                         NULL |                                    NULL |                                   NULL |                                     NULL |                       NULL |                     NULL |                       NULL |                    NULL |                 NULL |                     NULL |                          NULL |                           NULL |                      NULL |                                NULL |                                       NULL |                                           NULL |                                                NULL |                                                NULL |                                  NULL ...
# +-------+----------+----------------------------+--------------------+----------------------------+------------------------------------+-------------------------+-------------------------+---------------------+------------------------+-----------------------+--------------------------+----------------------+----------------------------------+----------------------------------+-----------------------+----------------------+--------------------------+---------------------+-------------------+--------------------------------+------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------+------------------------------------------+-----------------------------------+----------------------------------+----------------------------------+----------------------------------+------------------------------------+--------------------------------------------+------------------------------+----------------------------------------+---------------------------------------+-------------------------------------+--------------------------------------+---------------------------------------------+----------------------------------------------+----------------------------------------------+-------------------------------------------+------------------------------------------+--------------------------------------------+------------------------------------------+----------------------------------------+------------------------------------+------------------------------------------------+------------------------+--------------------+----------------------------------------+---------------------------------------+------------------------------------------+--------------------------------------+-------------------------------------------+--------------------------------------------+------------------------------------------+---------------------------------------+-------------------------------------------+---------------------------------+---------------------------------+-----------------------------------+-----------------------------------------------------------+---------------------------------------------------------+---------------------------------------------------+----------------------------------------+----------------------------+-------------------------------+-------------------------------+------------------------------+---------------------------+---------------------------+-----------------------------------------------+--------------------------------------------+----------------------------------------------+-------------------------------------------+-------------------------------------------+-----------------------------------------+------------------------------------+----------------------------------------+---------------------------+--------------------------------------------------------+-----------------------------------------------------+--------------------------------------------------+-----------------------------------------------+--------------------------------------------+---------------------------+------------------------------+------------------------+-------------------------+-----------------------------+------------------------------+-----------------------------------------+----------------------------------------+------------------------------------------+----------------------------+--------------------------+----------------------------+-------------------------+----------------------+--------------------------+-------------------------------+--------------------------------+---------------------------+-------------------------------------+--------------------------------------------+------------------------------------------------+-----------------------------------------------------+-----------------------------------------------------+-------------------------------------- ...

# %%
# !mysql -u root -proot -e "use neiva_output_db; select * from Property_Surrogate where S07='ARO2' and kOH>1e-10;"
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# +------+---------+---------------------------+----------------------------+------+------+-------+-------+---------+--------------------+------------------------+----------+------------------+--------------------+---------+---------------------------------+-------------------+----------+----------------------------+----------+--------------------+---------------------+---------------------------------------------------------+-------------------+
# | mm   | formula | compound                  | smile                      | S07  | S07T | S18B  | S22   | MOZT1   | kOH                | kOH_ref                | ko3_exp  | kno3_exp         | vp_nannoolal       | vp      | vp_ref                          | cstar             | hc_exp   | hc_exp_ref                 | hc_est   | OCratio            | oxidation_state     | id                                                      | geos_chem_species |
# +------+---------+---------------------------+----------------------------+------+------+-------+-------+---------+--------------------+------------------------+----------+------------------+--------------------+---------+---------------------------------+-------------------+----------+----------------------------+----------+--------------------+---------------------+---------------------------------------------------------+-------------------+
# | 67   | C4H5N   | Pyrrole                   | C1=CNC=C1                  | ARO2 | ARO2 | FURNS | FURNS | NULL    |      0.00000000011 | ATKINSON,R(1989)       | 1.57e-17 |   0.000000000049 |  1371.248605527029 |    8.36 | YAWS,CL (1994)                  |  9.69353972256774 | 0.000018 | HAWTHORNE,SB ET AL. (1985) | 0.000018 |                  0 |                   0 | InChI=1S/C4H5N/c1-2-4-5-3-1/h1-5H                       | NULL              |
# | 81   | C5H7N   | 1H-Pyrrole, 3-methyl-     | CC1=CNC=C1                 | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000200136 | EPI Estimate           |     NULL |             NULL |  408.6859734158758 |    5.54 | Mean of Antoine & Grain methods | 9.250223472281617 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C5H7N/c1-5-2-3-6-4-5/h2-4,6H,1H3               | NULL              |
# | 81   | C5H7N   | 1H-Pyrrole, 2-methyl-     | CC1=CC=CN1                 | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000200136 | EPI Estimate           |     NULL |             NULL |  26.34107511417325 |    4.61 | Mean of Antoine & Grain methods | 8.059467236581979 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C5H7N/c1-5-3-2-4-6-5/h2-4,6H,1H3               | NULL              |
# | 81   | C5H7N   | 1H-Pyrrole, 1-methyl-     | CN1C=CC=C1                 | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000110136 | EPI Estimate           |     NULL |             NULL |  368.0648392385954 |    21.4 | CHAO,J ET AL. (1983)            | 9.204758071646605 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C5H7N/c1-6-4-2-3-5-6/h2-5H,1H3                 | NULL              |
# | 95   | C6H9N   | 1H-Pyrrole, 2-ethyl-      | CCC1=CC=CN1                | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000002011013 | EPI Estimate           |     NULL |             NULL |  10.19457457613311 |    2.08 | Mean of Antoine & Grain methods | 7.716441433424415 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C6H9N/c1-2-6-4-3-5-7-6/h3-5,7H,2H2,1H3         | NULL              |
# | 95   | C6H9N   | 1H-Pyrrole, 1-ethyl-      | CCN1C=CC=C1                | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000001111013 | EPI Estimate           |     NULL |             NULL |  169.2608229394766 |    10.2 | Mean of Antoine & Grain methods | 8.936628774289613 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C6H9N/c1-2-7-5-3-4-6-7/h3-6H,2H2,1H3           | NULL              |
# | 95   | C6H9N   | 1H-Pyrrole, 2,5-dimethyl- | CC1=CC=C(N1)C              | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000200272 | EPI Estimate           |     NULL |             NULL | 0.4561652685023778 |   0.805 | NIST Web-site                   |  6.36719454212179 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C6H9N/c1-5-3-4-6(2)7-5/h3-4,7H,1-2H3           | NULL              |
# | 95   | C6H9N   | 1H-Pyrrole, 2,4-dimethyl- | CC1=CC(=CN1)C              | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000200272 | EPI Estimate           |     NULL |             NULL |  8.611065832186194 |    1.72 | Mean of Antoine & Grain methods | 7.643129235677469 |     NULL | NULL                       |     NULL |                  0 |                   0 | InChI=1S/C6H9N/c1-5-3-6(2)7-4-5/h3-4,7H,1-2H3           | NULL              |
# | 96   | C6H8O   | Furan, 3-ethyl-           | CCC1=COC=C1                | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000001017377 | EPI Estimate           |     NULL |             NULL |  147.3601193457213 |    25.9 | Mean of Antoine & Grain methods | 8.880999918557833 |     NULL | NULL                       |     NULL | 0.1666666666666667 |                  -1 | InChI=1S/C6H8O/c1-2-6-3-4-7-5-6/h3-5H,2H2,1H3           | NULL              |
# | 96   | C6H8O   | Furan, 2-ethyl-           | CCC1=CC=CO1                | ARO2 | ARO2 | FURNS | FURNS | XYLENES |     0.000000000108 | BIERBACH,AETAL.(1992)  |     NULL |             NULL |  10.19457457613311 |    52.7 | Mean of Antoine & Grain methods | 7.720989061175136 |     NULL | NULL                       |     NULL | 0.1666666666666667 |                  -1 | InChI=1S/C6H8O/c1-2-6-4-3-5-7-6/h3-5H,2H2,1H3           | NULL              |
# | 96   | C6H8O   | Furan, 2,5-dimethyl-      | CC1=CC=C(O1)C              | ARO2 | ARO2 | FURNS | FURNS | XYLENES |     0.000000000125 | ASCHMANN,SMETAL.(2011) |     NULL |             NULL | 0.4561652685023778 |    49.4 | Mean of Antoine & Grain methods | 6.371742169872511 |     NULL | NULL                       |     NULL | 0.1666666666666667 |                  -1 | InChI=1S/C6H8O/c1-5-3-4-6(2)7-5/h3-4H,1-2H3             | NULL              |
# | 96   | C6H8O   | Furan, 2,3-dimethyl-      | CC1=C(OC=C1)C              | ARO2 | ARO2 | FURNS | FURNS | NULL    |     0.000000000126 | ASCHMANN,SMETAL.(2011) |     NULL |             NULL |  11.18388645431214 |    25.9 | Mean of Antoine & Grain methods | 7.761212703172999 |     NULL | NULL                       |     NULL | 0.1666666666666667 |                  -1 | InChI=1S/C6H8O/c1-5-3-4-7-6(5)2/h3-4H,1-2H3             | NULL              |
# | 96   | C6H8O   | Furan, 2,4-dimethyl-      | CC1=CC(=CO1)C              | ARO2 | ARO2 | FURNS | FURNS | XYLENES |  0.000000000200272 | EPI Estimate           |     NULL |             NULL |  8.611065832186194 |    48.4 | Mean of Antoine & Grain methods |  7.64767686342819 |     NULL | NULL                       |     NULL | 0.1666666666666667 |                  -1 | InChI=1S/C6H8O/c1-5-3-6(2)7-4-5/h3-4H,1-2H3             | NULL              |
# | 108  | C7H8O   | Furan, 2-(2-propenyl)-    | C=CCC1=CC=CO1              | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000001278704 | EPI Estimate           |     NULL |             NULL |  3.790386243669413 |    9.99 | Mean of Antoine & Grain methods |  7.34245594363098 |     NULL | NULL                       |     NULL | 0.1428571428571428 | -0.8571428571428571 | InChI=1S/C7H8O/c1-2-4-7-5-3-6-8-7/h2-3,5-6H,1,4H2       | NULL              |
# | 110  | C7H10O  | Furan, 2-propyl-          | CCCC1=CC=CO1               | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000001031013 | EPI Estimate           |     NULL |             NULL |  3.520971247658832 |    19.5 | Mean of Antoine & Grain methods | 7.318403884716954 |     NULL | NULL                       |     NULL | 0.1428571428571428 |  -1.142857142857143 | InChI=1S/C7H10O/c1-2-4-7-5-3-6-8-7/h3,5-6H,2,4H2,1H3    | NULL              |
# | 110  | C7H10O  | Furan, 2-ethyl-5-methyl-  | CCC1=CC=C(O1)C             | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000001300489 | EPI Estimate           |     NULL |             NULL | 0.1946758290331903 |    16.7 | Mean of Antoine & Grain methods |  6.06105343892107 |     NULL | NULL                       |     NULL | 0.1428571428571428 |  -1.142857142857143 | InChI=1S/C7H10O/c1-3-7-5-4-6(2)8-7/h4-5H,3H2,1-2H3      | NULL              |
# | 110  | C7H10O  | Furan, 2,3,5-trimethyl-   | CC1=CC(=C(O1)C)C           | ARO2 | ARO2 | FURNS | FURNS | NULL    |  0.000000000200408 | EPI Estimate           |     NULL |             NULL | 0.1591150167303365 |    9.25 | Mean of Antoine & Grain methods | 5.973452574898761 |     NULL | NULL                       |     NULL | 0.1428571428571428 |  -1.142857142857143 | InChI=1S/C7H10O/c1-5-4-6(2)8-7(5)3/h4H,1-3H3            | NULL              |
# | 124  | C8H12O  | Furan, 4-methyl-2-propyl- | CCCC1=CC(=CO1)C            | ARO2 | ARO2 | FURNS | FURNS | NULL    | 0.0000000002026009 | EPI Estimate           |     NULL |             NULL |  1.205334623866464 |    3.31 | Mean of Antoine & Grain methods | 6.904878038172429 |     NULL | NULL                       |     NULL |              0.125 |               -1.25 | InChI=1S/C8H12O/c1-3-4-8-5-7(2)6-9-8/h5-6H,3-4H2,1-2H3  | NULL              |
# | 152  | C12H8   | Acenaphthylene            | C1=CC2=C3C(=C1)C=CC3=CC=C2 | ARO2 | ARO2 | NAPS  | NAPS  | NROG    |     0.000000000109 | ZHOU,S&WENGER,JC(2013) | 3.99e-16 | 0.00000000000442 |   1.59965542653508 | 0.00668 | SONNEFELD,WJ ET AL. (1983)      |  7.11621875249051 | 0.000114 | WARNER,HP ET AL. (1987)    | 0.000114 |                  0 |                   0 | InChI=1S/C12H8/c1-3-9-4-2-6-11-8-7-10(5-1)12(9)11/h1-8H | NULL              |
# +------+---------+---------------------------+----------------------------+------+------+-------+-------+---------+--------------------+------------------------+----------+------------------+--------------------+---------+---------------------------------+-------------------+----------+----------------------------+----------+--------------------+---------------------+---------------------------------------------------------+-------------------+

# %% [markdown]
# ## **3. Download tables**

# %% [markdown]
# ## **3.1 Import the 'neivapy' package and other essential python libraries**

# %%
import NEIVA.neivapy as nv
import pandas as pd
from sqlalchemy import text
from google.colab import files

# %% [markdown]
# ## **3.2 Connect the databases**

# %%
bk_db=nv.connect_db('backend_db')
primary_db=nv.connect_db('primary_db')
raw_db=nv.connect_db('raw_db')
legacy_db=nv.connect_db('legacy_db')
neiva_output_db=nv.connect_db('neiva_output_db')

# %% [markdown]
# ## **3.3 Read tables as dataframe and download**

# %%
dd=pd.read_sql(text('select * from Recommended_EF'), con=neiva_output_db)

# %%
dd.to_csv('example.csv', index=False)

# %%
# !ls
# Out:
# example.csv  NEIVA  sample_data

# %%
files.download('example.csv')

# %%
# download tables from databases
#__________ Specify database name and connection ____
db_name='legacy_db'
db_con=legacy_db
#____________________________________________________
tbl_ll=nv.get_table_name(db_name)
tbl_ll

# %%
tbl_ll=tbl_ll[:2]

# %%
for table in tbl_ll:
    dd=pd.read_sql(text('select * from '+table), con=db_con)
    dd.to_csv(table+'.csv', index=False)
    files.download(table+'.csv')
    # Process column names
    print('Table name :'+table)
    print('column names :'+','.join(dd.columns))
